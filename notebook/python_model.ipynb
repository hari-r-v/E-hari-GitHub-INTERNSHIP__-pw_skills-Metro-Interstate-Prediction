# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# Out:
# <frozen importlib._bootstrap>:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 216 from C header, got 232 from PyObject

# %%
df=pd.read_csv('Metro_Interstate_Traffic_Volume.csv')

# %%
df.head()
# Out:
#   holiday    temp  rain_1h  snow_1h  clouds_all weather_main  \
# 0    None  288.28      0.0      0.0          40       Clouds
# 1    None  289.36      0.0      0.0          75       Clouds
# 2    None  289.58      0.0      0.0          90       Clouds
# 3    None  290.13      0.0      0.0          90       Clouds
# 4    None  291.14      0.0      0.0          75       Clouds
#
#   weather_description            date_time  traffic_volume
# 0    scattered clouds  2012-10-02 09:00:00            5545
# 1       broken clouds  2012-10-02 10:00:00            4516
# 2     overcast clouds  2012-10-02 11:00:00            4767
# 3     overcast clouds  2012-10-02 12:00:00            5026
# 4       broken clouds  2012-10-02 13:00:00            4918

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48204 entries, 0 to 48203
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   holiday              48204 non-null  object
#  1   temp                 48204 non-null  float64
#  2   rain_1h              48204 non-null  float64
#  3   snow_1h              48204 non-null  float64
#  4   clouds_all           48204 non-null  int64
#  5   weather_main         48204 non-null  object
#  6   weather_description  48204 non-null  object
#  7   date_time            48204 non-null  object
#  8   traffic_volume       48204 non-null  int64
# dtypes: float64(3), int64(2), object(4)
# memory usage: 3.3+ MB

# %%
df.columns
# Out:
# Index(['holiday', 'temp', 'rain_1h', 'snow_1h', 'clouds_all', 'weather_main',
#        'weather_description', 'date_time', 'traffic_volume'],
#       dtype='object')

# %%
for x in df.columns:
    print("/nUnique value counts",df[x].value_counts())
    print("************************************************")
# Out:
# /nUnique value counts None                         48143
# Labor Day                        7
# Christmas Day                    6
# Martin Luther King Jr Day        6
# Thanksgiving Day                 6
# New Years Day                    6
# Independence Day                 5
# Columbus Day                     5
# State Fair                       5
# Veterans Day                     5
# Washingtons Birthday             5
# Memorial Day                     5
# Name: holiday, dtype: int64
# ************************************************
# /nUnique value counts 274.150    128
# 275.150     89
# 274.080     85
# 276.793     78
# 291.150     73
#           ...
# 248.700      1
# 279.130      1
# 284.789      1
# 280.850      1
# 253.410      1
# Name: temp, Length: 5843, dtype: int64
# ************************************************
# /nUnique value counts 0.00     44737
# 0.25       948
# 0.51       256
# 1.02       123
# 0.30       121
#          ...
# 5.11         1
# ...

# %%
df.describe()
# Out:
#                temp       rain_1h       snow_1h    clouds_all  traffic_volume
# count  48204.000000  48204.000000  48204.000000  48204.000000    48204.000000
# mean     281.205870      0.334264      0.000222     49.362231     3259.818355
# std       13.338232     44.789133      0.008168     39.015750     1986.860670
# min        0.000000      0.000000      0.000000      0.000000        0.000000
# 25%      272.160000      0.000000      0.000000      1.000000     1193.000000
# 50%      282.450000      0.000000      0.000000     64.000000     3380.000000
# 75%      291.806000      0.000000      0.000000     90.000000     4933.000000
# max      310.070000   9831.300000      0.510000    100.000000     7280.000000

# %%
df.isna().sum()
# Out:
# holiday                0
# temp                   0
# rain_1h                0
# snow_1h                0
# clouds_all             0
# weather_main           0
# weather_description    0
# date_time              0
# traffic_volume         0
# dtype: int64

# %%
df_copy= df

# %%
row = df_copy.columns
plt.figure(figsize=(20,15))
for i in range(len(row)):
    plt.subplot(4,3,i+1)
    plt.hist(df_copy[[df_copy.columns[i]]],bins=50)
    plt.title(df_copy.columns[i])
plt.show()

# %%
df.columns
# Out:
# Index(['holiday', 'temp', 'rain_1h', 'snow_1h', 'clouds_all', 'weather_main',
#        'weather_description', 'date_time', 'traffic_volume'],
#       dtype='object')

# %%
plt.figure(figsize=(15,12))
sns.barplot(x=df['holiday'], y=df['traffic_volume'])
plt.title('airline  Vs Price')
plt.xlabel('airline')
plt.ylabel('Price')
plt.show()

# %%
df['holiday'].value_counts()
# Out:
# None                         48143
# Labor Day                        7
# Christmas Day                    6
# Martin Luther King Jr Day        6
# Thanksgiving Day                 6
# New Years Day                    6
# Independence Day                 5
# Columbus Day                     5
# State Fair                       5
# Veterans Day                     5
# Washingtons Birthday             5
# Memorial Day                     5
# Name: holiday, dtype: int64

# %%
df[df['holiday']=='Columbus Day']
# Out:
#             holiday     temp  rain_1h  snow_1h  clouds_all weather_main  \
# 126    Columbus Day  273.080      0.0      0.0          20       Clouds
# 9455   Columbus Day  277.720      0.0      0.0           0        Clear
# 18946  Columbus Day  293.020      0.0      0.0           1        Clear
# 27224  Columbus Day  282.341      0.0      0.0           0        Clear
# 37882  Columbus Day  284.620      0.0      0.0           1        Clear
#
#       weather_description            date_time  traffic_volume
# 126            few clouds  2012-10-08 00:00:00             455
# 9455         Sky is Clear  2013-10-14 00:00:00             615
# 18946        sky is clear  2015-10-12 00:00:00             494
# 27224        Sky is Clear  2016-10-10 00:00:00             484
# 37882        sky is clear  2017-10-09 00:00:00             549

# %%
row
# Out:
# Index(['holiday', 'temp', 'rain_1h', 'snow_1h', 'clouds_all', 'weather_main',
#        'weather_description', 'date_time', 'traffic_volume'],
#       dtype='object')

# %%
row = list(df.columns)

# %%
row
# Out:
# ['holiday',
#  'temp',
#  'rain_1h',
#  'snow_1h',
#  'clouds_all',
#  'weather_main',
#  'weather_description',
#  'date_time',
#  'traffic_volume']

# %%
row.remove('traffic_volume')
row
# Out:
# ['holiday',
#  'temp',
#  'rain_1h',
#  'snow_1h',
#  'clouds_all',
#  'weather_main',
#  'weather_description',
#  'date_time']

# %%
df[df['temp']==0]
# Out:
#       holiday  temp  rain_1h  snow_1h  clouds_all weather_main  \
# 11898    None   0.0      0.0      0.0           0        Clear
# 11899    None   0.0      0.0      0.0           0        Clear
# 11900    None   0.0      0.0      0.0           0        Clear
# 11901    None   0.0      0.0      0.0           0        Clear
# 11946    None   0.0      0.0      0.0           0        Clear
# 11947    None   0.0      0.0      0.0           0        Clear
# 11948    None   0.0      0.0      0.0           0        Clear
# 11949    None   0.0      0.0      0.0           0        Clear
# 11950    None   0.0      0.0      0.0           0        Clear
# 11951    None   0.0      0.0      0.0           0        Clear
#
#       weather_description            date_time  traffic_volume
# 11898        sky is clear  2014-01-31 03:00:00             361
# 11899        sky is clear  2014-01-31 04:00:00             734
# 11900        sky is clear  2014-01-31 05:00:00            2557
# ...

# %%
df['weather_description'].value_counts()
# Out:
# sky is clear                           11665
# mist                                    5950
# overcast clouds                         5081
# broken clouds                           4666
# scattered clouds                        3461
# light rain                              3372
# few clouds                              1956
# light snow                              1946
# Sky is Clear                            1726
# moderate rain                           1664
# haze                                    1360
# light intensity drizzle                 1100
# fog                                      912
# proximity thunderstorm                   673
# drizzle                                  651
# heavy snow                               616
# heavy intensity rain                     467
# snow                                     293
# proximity shower rain                    136
# thunderstorm                             125
# heavy intensity drizzle                   64
# ...

# %%
sns.scatterplot(x=df_copy['temp'],y=df_copy['traffic_volume'])
plt.show()

# %%
df[df['temp']<200]
# Out:
#       holiday  temp  rain_1h  snow_1h  clouds_all weather_main  \
# 11898    None   0.0      0.0      0.0           0        Clear
# 11899    None   0.0      0.0      0.0           0        Clear
# 11900    None   0.0      0.0      0.0           0        Clear
# 11901    None   0.0      0.0      0.0           0        Clear
# 11946    None   0.0      0.0      0.0           0        Clear
# 11947    None   0.0      0.0      0.0           0        Clear
# 11948    None   0.0      0.0      0.0           0        Clear
# 11949    None   0.0      0.0      0.0           0        Clear
# 11950    None   0.0      0.0      0.0           0        Clear
# 11951    None   0.0      0.0      0.0           0        Clear
#
#       weather_description            date_time  traffic_volume
# 11898        sky is clear  2014-01-31 03:00:00             361
# 11899        sky is clear  2014-01-31 04:00:00             734
# 11900        sky is clear  2014-01-31 05:00:00            2557
# ...

# %%
obj = []
for x in df.columns:
    if (df[x].dtypes=='object') & (x!='date_time'):
        obj.append(x)

# %%
obj
# Out:
# ['holiday', 'weather_main', 'weather_description']

# %%
df.head()
# Out:
#   holiday    temp  rain_1h  snow_1h  clouds_all weather_main  \
# 0    None  288.28      0.0      0.0          40       Clouds
# 1    None  289.36      0.0      0.0          75       Clouds
# 2    None  289.58      0.0      0.0          90       Clouds
# 3    None  290.13      0.0      0.0          90       Clouds
# 4    None  291.14      0.0      0.0          75       Clouds
#
#   weather_description            date_time  traffic_volume
# 0    scattered clouds  2012-10-02 09:00:00            5545
# 1       broken clouds  2012-10-02 10:00:00            4516
# 2     overcast clouds  2012-10-02 11:00:00            4767
# 3     overcast clouds  2012-10-02 12:00:00            5026
# 4       broken clouds  2012-10-02 13:00:00            4918

# %%
from sklearn import preprocessing
l_en_code = preprocessing.LabelEncoder()
for x in obj:
    df[x]=l_en_code.fit_transform(df[x])

# %%
df.head()
# Out:
#    holiday    temp  rain_1h  snow_1h  clouds_all  weather_main  \
# 0        7  288.28      0.0      0.0          40             1
# 1        7  289.36      0.0      0.0          75             1
# 2        7  289.58      0.0      0.0          90             1
# 3        7  290.13      0.0      0.0          90             1
# 4        7  291.14      0.0      0.0          75             1
#
#    weather_description            date_time  traffic_volume
# 0                   24  2012-10-02 09:00:00            5545
# 1                    2  2012-10-02 10:00:00            4516
# 2                   19  2012-10-02 11:00:00            4767
# 3                   19  2012-10-02 12:00:00            5026
# 4                    2  2012-10-02 13:00:00            4918

# %% [markdown]
# - None                                  :48143
# - Labor Day                             :7
# - Christmas Day                         :6
# - Martin Luther King Jr Day             :6
# - Thanksgiving Day                      :6
# - New Years Day                         :6
# - Independence Day                      :5
# - Columbus Day                          :5
# - State Fair                            :5
# - Veterans Day                          :5
# - Washingtons Birthday                  :5
# - Memorial Day                          :5
# ##### Name: holiday, dtype: int64

# %%
df['holiday'].value_counts()
# Out:
# 7     48143
# 3         7
# 9         6
# 6         6
# 4         6
# 0         6
# 11        5
# 10        5
# 8         5
# 5         5
# 2         5
# 1         5
# Name: holiday, dtype: int64
